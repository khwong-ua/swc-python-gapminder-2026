# %% [markdown]
# # Python SWC Workshop September 2026
# Kenny Wong

# %%
age = 38
first_name = 'Kenny'
last_name = 'Wong'

# %%
print(first_name, last_name,'is',age,'years old')
print('Hello world!')
# Out:
# Kenny Wong is 38 years old
# Hello world!

# %%
print(last_name)
# Out:
# Wong

# %%
age_in_3 = age+3
print(first_name, 'will be', age_in_3, 'in three years.')
# Out:
# Kenny will be 41 in three years.

# %%
first_name, last_name
# Out:
# ('Kenny', 'Wong')

# %%
first_name[0]
# Out:
# 'K'

# %%
first_name[-1]
# Out:
# 'y'

# %%
first_name[-2]
# Out:
# 'n'

# %%
first_name[-1], first_name[-2], first_name[-3], first_name[-4], first_name[-5]
# Out:
# ('y', 'n', 'n', 'e', 'K')
