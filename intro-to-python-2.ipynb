# %% [markdown]
# # Starting Over Day 2 Notebook!

# %% [markdown]
# **To-do List:**
# * recreate dataframes from gapminder data
# * recreate plotting section

# %%
import pandas as pd

# %%
goals = [1, 'Create lists.', 2, 'Extract items from lists.', 3, 'Modify lists.']

# %%
values = []
values.append(1)
values.append(3)
values.append(5)
print('first time:', values)
values = values[1:]
print('second time:', values)
# Out:
# first time: [1, 3, 5]
# second time: [3, 5]

# %%
for number in [2,3,5,7]:
    print(number)
# Out:
# 2
# 3
# 5
# 7

# %%
primes = [2,3,5]
for p in primes:
    squared = p ** 2
    cubed = p ** 3
    print(p,'(^2):',squared,'(^3):',cubed)
# Out:
# 2 (^2): 4 (^3): 8
# 3 (^2): 9 (^3): 27
# 5 (^2): 25 (^3): 125

# %%
print('a range is not a list: range(0,3)')
for number in range(0,3):
    print(number)
# Out:
# a range is not a list: range(0,3)
# 0
# 1
# 2

# %%
print('a range is not a list: range(0,11)')
for i in range(0,11,2):
    print(i)
# Out:
# a range is not a list: range(0,11)
# 0
# 2
# 4
# 6
# 8
# 10

# %%
total = 0
for number in range(10):
    total = total + number
    print(total,number)
# Out:
# 0 0
# 1 1
# 3 2
# 6 3
# 10 4
# 15 5
# 21 6
# 28 7
# 36 8
# 45 9

# %%
velocity = 10.0
for i in range(5): # execute the loop 5 times
    print(i, ':', velocity)
    if velocity > 20.0:
        print('moving too fast')
        velocity = velocity - 5.0
    else:
        print('moving too slow')
        velocity = velocity + 10.0
print('final velocity:', velocity)
# Out:
# 0 : 10.0
# moving too slow
# 1 : 20.0
# moving too slow
# 2 : 30.0
# moving too fast
# 3 : 25.0
# moving too fast
# 4 : 20.0
# moving too slow
# final velocity: 30.0

# %%
def print_greeting():
    print('Hello!')
    print('The weather is nice today.')
    print('Right?')

# %%
print_greeting()
# Out:
# Hello!
# The weather is nice today.
# Right?

# %%
def print_date(year,month,day):
    joined = str(year) + '/' + str(month) + '/' + str(day)
    print(joined)
    # return None

result = print_date(month=3,day=30,year=2026)
print(result)
# Out:
# 2026/3/30
# None

# %%
def average(values):
    if len(values) == 0:
        return None
    return sum(values)/len(values)

values = []
average(values)
